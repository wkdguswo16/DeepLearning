# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Test = pd.read_csv('./data/DailyDelhiClimateTest.csv', )

# %%
Test
# Out:
#            date   meantemp   humidity  wind_speed  meanpressure
# 0    2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1    2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2    2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3    2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4    2017-01-05  18.388889  74.944444    3.300000   1014.333333
# ..          ...        ...        ...         ...           ...
# 109  2017-04-20  34.500000  27.500000    5.562500    998.625000
# 110  2017-04-21  34.250000  39.375000    6.962500    999.875000
# 111  2017-04-22  32.900000  40.900000    8.890000   1001.600000
# 112  2017-04-23  32.875000  27.500000    9.962500   1002.125000
# 113  2017-04-24  32.000000  27.142857   12.157143   1004.142857
#
# [114 rows x 5 columns]

# %%
Train = pd.read_csv('./data/DailyDelhiClimateTrain.csv', )

# %%
Train
# Out:
#             date   meantemp    humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
Train.shape
# Out:
# (1462, 5)

# %%
def MinMaxScaler(data):
    numerator = data - np.min(data, 0)
    denominator = np.max(data, 0) - np.min(data, 0)

    return numerator / (denominator + 1e-7)

# %%
X_train = Train[['meantemp', 'humidity', 'wind_speed', 'meanpressure']]
X_train = MinMaxScaler(X_train)

y_train = X_train[['meantemp']]
X_train = X_train[['humidity', 'wind_speed', 'meanpressure']]

X_train
# Out:
#       humidity  wind_speed  meanpressure
# 0     0.820957    0.000000      0.132603
# 1     0.907591    0.070583      0.132881
# 2     0.849835    0.109743      0.132994
# 3     0.668867    0.029212      0.132799
# 4     0.847910    0.087636      0.132712
# ...        ...         ...           ...
# 1457  0.630865    0.084032      0.132590
# 1458  0.859736    0.142113      0.132764
# 1459  0.880638    0.148429      0.132895
# 1460  0.849835    0.173496      0.132660
# 1461  1.000000    0.000000      0.132647
#
# [1462 rows x 3 columns]

# %%
X_test = Test[['meantemp', 'humidity', 'wind_speed', 'meanpressure']]
X_test = MinMaxScaler(X_test)

y_test = X_test[['meantemp']]
X_test = X_test[['humidity', 'wind_speed', 'meanpressure']]

X_test
# Out:
#      humidity  wind_speed  meanpressure
# 0    0.872396    0.075640      0.000000
# 1    0.761651    0.084061      0.995298
# 2    0.821416    0.146661      0.995356
# 3    0.669797    0.176133      0.992624
# 4    0.732480    0.106684      0.991206
# ..        ...         ...           ...
# 109  0.124867    0.232892      0.974907
# 110  0.276948    0.310987      0.976204
# 111  0.296478    0.418508      0.977994
# 112  0.124867    0.478334      0.978539
# 113  0.120293    0.600757      0.980632
#
# [114 rows x 3 columns]

# %%
time_step = 7
step = 1

def create_dataset(X, y, time_step, step):
    Xs, ys = [], []

    for i in range(0, len(X) - time_step, step):
        v = X.iloc[i : (i + time_step)].values
        labels = y.iloc[i + time_step]

        Xs.append(v)
        ys.append(labels)

    return np.array(Xs), np.array(ys)

# %%
train_X, train_y = create_dataset(X_train, y_train, time_step, step)

train_X.shape, train_y.shape
# Out:
# ((1455, 7, 3), (1455, 1))

# %%
test_X, test_y = create_dataset(X_test, y_test, time_step, step)
test_X.shape, test_y.shape
# Out:
# ((107, 7, 3), (107, 1))

# %%
n_timesteps,n_features,n_outputs=train_X.shape[1],train_X.shape[2],train_y.shape[1]

# %%
n_timesteps, n_features, n_outputs
# Out:
# (7, 3, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Dropout, Conv1D, MaxPooling1D, Flatten

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_timesteps,n_features)))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Dropout(0.5))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(n_outputs, activation='linear'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 5, 64)             640
#
#  conv1d_1 (Conv1D)           (None, 3, 64)             12352
#
#  dropout (Dropout)           (None, 3, 64)             0
#
#  max_pooling1d (MaxPooling1D  (None, 1, 64)            0
#  )
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 17,217
# Trainable params: 17,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam')

# %%
history = model.fit(train_X, train_y, epochs=100, batch_size=32, validation_split=(0.2), shuffle=False)
# Out:
# Epoch 1/100
# 37/37 [==============================] - 1s 7ms/step - loss: 0.1180 - val_loss: 0.1233
# Epoch 2/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0625 - val_loss: 0.0888
# Epoch 3/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0523 - val_loss: 0.0978
# Epoch 4/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0469 - val_loss: 0.0904
# Epoch 5/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0465 - val_loss: 0.0825
# Epoch 6/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0445 - val_loss: 0.0812
# Epoch 7/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0440 - val_loss: 0.0779
# Epoch 8/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0418 - val_loss: 0.0757
# Epoch 9/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0410 - val_loss: 0.0750
# Epoch 10/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0414 - val_loss: 0.0740
# Epoch 11/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0402 - val_loss: 0.0705
# Epoch 12/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0395 - val_loss: 0.0692
# Epoch 13/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0395 - val_loss: 0.0692
# Epoch 14/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0396 - val_loss: 0.0653
# Epoch 15/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0376 - val_loss: 0.0620
# Epoch 16/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0379 - val_loss: 0.0594
# Epoch 17/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0374 - val_loss: 0.0606
# Epoch 18/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0369 - val_loss: 0.0535
# Epoch 19/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0375 - val_loss: 0.0565
# Epoch 20/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0378 - val_loss: 0.0561
# Epoch 21/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0369 - val_loss: 0.0546
# Epoch 22/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0364 - val_loss: 0.0547
# Epoch 23/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0363 - val_loss: 0.0525
# Epoch 24/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0365 - val_loss: 0.0521
# Epoch 25/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0367 - val_loss: 0.0507
# Epoch 26/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0359 - val_loss: 0.0497
# Epoch 27/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0358 - val_loss: 0.0502
# Epoch 28/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0357 - val_loss: 0.0494
# Epoch 29/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0356 - val_loss: 0.0484
# Epoch 30/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0350 - val_loss: 0.0471
# Epoch 31/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0351 - val_loss: 0.0472
# Epoch 32/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0356 - val_loss: 0.0489
# Epoch 33/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0350 - val_loss: 0.0472
# Epoch 34/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0351 - val_loss: 0.0462
# Epoch 35/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0347 - val_loss: 0.0465
# Epoch 36/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0350 - val_loss: 0.0487
# Epoch 37/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0341 - val_loss: 0.0471
# Epoch 38/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0346 - val_loss: 0.0476
# Epoch 39/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0350 - val_loss: 0.0471
# Epoch 40/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0343 - val_loss: 0.0455
# Epoch 41/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0348 - val_loss: 0.0456
# Epoch 42/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0349 - val_loss: 0.0439
# Epoch 43/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0343 - val_loss: 0.0450
# Epoch 44/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0342 - val_loss: 0.0467
# Epoch 45/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0342 - val_loss: 0.0458
# Epoch 46/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0345 - val_loss: 0.0449
# Epoch 47/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0341 - val_loss: 0.0447
# Epoch 48/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0344 - val_loss: 0.0444
# Epoch 49/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0341 - val_loss: 0.0449
# Epoch 50/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0341 - val_loss: 0.0447
# Epoch 51/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0343 - val_loss: 0.0438
# Epoch 52/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0338 - val_loss: 0.0434
# Epoch 53/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0340 - val_loss: 0.0450
# Epoch 54/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0339 - val_loss: 0.0442
# Epoch 55/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0339 - val_loss: 0.0438
# Epoch 56/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0336 - val_loss: 0.0437
# Epoch 57/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0341 - val_loss: 0.0447
# Epoch 58/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0337 - val_loss: 0.0440
# Epoch 59/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0335 - val_loss: 0.0448
# Epoch 60/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0336 - val_loss: 0.0442
# Epoch 61/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0333 - val_loss: 0.0455
# Epoch 62/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0332 - val_loss: 0.0441
# Epoch 63/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0332 - val_loss: 0.0424
# Epoch 64/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0332 - val_loss: 0.0425
# Epoch 65/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0335 - val_loss: 0.0428
# Epoch 66/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0329 - val_loss: 0.0432
# Epoch 67/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0329 - val_loss: 0.0431
# Epoch 68/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0331 - val_loss: 0.0429
# Epoch 69/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0328 - val_loss: 0.0413
# Epoch 70/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0329 - val_loss: 0.0422
# Epoch 71/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0332 - val_loss: 0.0431
# Epoch 72/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0328 - val_loss: 0.0427
# Epoch 73/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0325 - val_loss: 0.0416
# Epoch 74/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0319 - val_loss: 0.0432
# Epoch 75/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0322 - val_loss: 0.0414
# Epoch 76/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0322 - val_loss: 0.0413
# Epoch 77/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0326 - val_loss: 0.0411
# Epoch 78/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0324 - val_loss: 0.0426
# Epoch 79/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0317 - val_loss: 0.0404
# Epoch 80/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0323 - val_loss: 0.0406
# Epoch 81/100
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0323 - val_loss: 0.0411
# Epoch 82/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0321 - val_loss: 0.0426
# Epoch 83/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0322 - val_loss: 0.0414
# Epoch 84/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0317 - val_loss: 0.0420
# Epoch 85/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0318 - val_loss: 0.0408
# Epoch 86/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0316 - val_loss: 0.0401
# Epoch 87/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0316 - val_loss: 0.0394
# Epoch 88/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0317 - val_loss: 0.0402
# Epoch 89/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0312 - val_loss: 0.0402
# Epoch 90/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0317 - val_loss: 0.0398
# Epoch 91/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0317 - val_loss: 0.0394
# Epoch 92/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0310 - val_loss: 0.0400
# Epoch 93/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0311 - val_loss: 0.0394
# Epoch 94/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0314 - val_loss: 0.0390
# Epoch 95/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0305 - val_loss: 0.0393
# Epoch 96/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0308 - val_loss: 0.0400
# Epoch 97/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0305 - val_loss: 0.0400
# Epoch 98/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0309 - val_loss: 0.0407
# Epoch 99/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0303 - val_loss: 0.0402
# Epoch 100/100
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0310 - val_loss: 0.0390

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

x = np.arange(0, len(history.history['loss']))

plt.plot(x, loss, 'y', label='loss')
plt.plot(x, val_loss, 'r', label='val loss')
plt.title('Losses')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
y_pred = model.predict(test_X)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3237
# 4/4 [==============================] - 0s 2ms/step

# %%
y_pred.shape

plt.plot(y_test, color='red', label='real stock price')
plt.plot(y_pred, color='blue', label='predicted stock price')
plt.title('stock price prediction')
plt.xlabel('time')
plt.ylabel('stock price')
plt.legend()
plt.show()
